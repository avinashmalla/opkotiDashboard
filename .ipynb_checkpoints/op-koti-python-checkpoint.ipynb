# %% [markdown]
# # Data collected from OP's website op-koti.fi. Initially I used webscraping technique to collect data. But using the API was more dynamic and easy to handle

# %%
import numpy as np
import pandas as pd
import requests
# import math
import re
from pandas import json_normalize

# %%
URL = 'https://op-koti.fi/api/apartments?mode=sale&featureGroup=apartment&orderBy=created&order=desc&offset=0&limit=4500'
# request the URL and parse the JSON
response = requests.get(URL)
response.raise_for_status() # raise exception if invalid response
data = response.json()['listings']

# normalizing the json data into a dataframe
df = json_normalize(data, max_level = 1)

# %%
df.head(10)
# Out:
#        id kipinaId  listingType commission  listingGroup  source  \
# 0  692440   417138           90          K            82  Kipinä
# 1  507032   431746           90          K            82  Kipinä
# 2  506809   431523           91          O            82  Kipinä
# 3  698329   423026           90          K            82  Kipinä
# 4  507990   432702           91          O            82  Kipinä
# 5  508029   432741           91          O            82  Kipinä
# 6  699096   423794           89          O            82  Kipinä
# 7  507879   432591           89          O            82  Kipinä
# 8  507358   432071           90          K            82  Kipinä
# 9  507097   431811           89          O            82  Kipinä
#
#                     created featureGroups  floor    year  ... siteArea.size  \
# 0  2021-06-01T09:06:09.931Z   [apartment]    0.0  1991.0  ...         986.0
# 1  2021-06-01T09:05:46.712Z   [apartment]    0.0  1969.0  ...        1200.0
# 2  2021-06-01T09:05:44.681Z   [apartment]    1.0  1989.0  ...        2584.0
# 3  2021-06-01T08:07:41.137Z   [apartment]    0.0  2009.0  ...        2130.0
# 4  2021-06-01T08:07:06.259Z   [apartment]    1.0  1990.0  ...        4056.0
# 5  2021-06-01T08:07:05.548Z   [apartment]    1.0  1989.0  ...        5959.0
# 6  2021-06-01T07:06:31.042Z   [apartment]    1.0  1963.0  ...        2280.0
# 7  2021-06-01T07:06:12.453Z   [apartment]    2.0  1914.0  ...        1355.0
# 8  2021-06-01T07:06:11.073Z   [apartment]    0.0  2006.0  ...        2112.0
# 9  2021-06-01T07:06:05.402Z   [apartment]    1.0  1974.0  ...       10204.0
#
#   siteArea.displayUnit pricing.debtFreePrice  siteArea  \
# 0                   m2                   NaN       NaN
# 1                   m2                   NaN       NaN
# 2                   m2              137000.0       NaN
# 3                   m2                   NaN       NaN
# 4                   m2               58500.0       NaN
# 5                   m2              127000.0       NaN
# 6                   m2               69000.0       NaN
# 7                   m2              298000.0       NaN
# 8                   m2                   NaN       NaN
# 9                   m2               62000.0       NaN
#
#    virtualPresentationUrl  videoUrl livingArea totalArea  \
# 0                     NaN       NaN        NaN       NaN
# 1                     NaN       NaN        NaN       NaN
# 2                     NaN       NaN        NaN       NaN
# 3                     NaN       NaN        NaN       NaN
# 4                     NaN       NaN        NaN       NaN
# 5                     NaN       NaN        NaN       NaN
# 6                     NaN       NaN        NaN       NaN
# 7                     NaN       NaN        NaN       NaN
# 8                     NaN       NaN        NaN       NaN
# 9                     NaN       NaN        NaN       NaN
#
#   newHousing.newHousingId newHousing.name
# 0                     NaN             NaN
# 1                     NaN             NaN
# 2                     NaN             NaN
# 3                     NaN             NaN
# 4                     NaN             NaN
# 5                     NaN             NaN
# 6                     NaN             NaN
# 7                     NaN             NaN
# 8                     NaN             NaN
# 9                     NaN             NaN
#
# [10 rows x 48 columns]

# %% [markdown]
# It can be seen above that the dataframe contains multiple columns that are irrelevant to us. Relevant columns are selected as shown below.

# %%
df.columns
# Out:
# Index(['id', 'kipinaId', 'listingType', 'commission', 'listingGroup', 'source',
#        'created', 'featureGroups', 'floor', 'year', 'imageUrl', 'showings',
#        'rooms', 'numberOfRooms', 'price', 'debtFreePrice', 'rentPerMonth',
#        'location.streetAddress', 'location.postalCode', 'location.postOffice',
#        'location.city', 'location.cityId', 'location.region',
#        'location.regionId', 'location.district', 'location.districtId',
#        'location.streetId', 'location.coordinates', 'housing.livingArea',
#        'housing.totalArea', 'housing.siteArea', 'housing.rooms',
#        'housing.numberOfRooms', 'pricing.price', 'livingArea.size',
#        'livingArea.displayUnit', 'totalArea.size', 'totalArea.displayUnit',
#        'siteArea.size', 'siteArea.displayUnit', 'pricing.debtFreePrice',
#        'siteArea', 'virtualPresentationUrl', 'videoUrl', 'livingArea',
#        'totalArea', 'newHousing.newHousingId', 'newHousing.name'],
#       dtype='object')

# %%
cols = ['id', 'listingType', 'floor', 'year', 'rooms', 'numberOfRooms', 'price',
       'location.city', 'location.region', 'location.district','location.postalCode',
       'livingArea.size', 'totalArea.size']

df = df[cols]

# %% [markdown]
# Renaming the cols

# %%
df = df.rename(columns = {'location.city':'city','location.region':'region','location.district':'district','location.postalCode':'postalCode','livingArea.size':'livingArea','totalArea.size':'totalArea', 'year':'yearBuilt'})

# %% [markdown]
# Mapping the listingType column to the apporpriate type of house (extracted from the website manually)

# %%
lType = {89:'Kerrostalo',90:'Omakotitalo',91:'Rivitalo',92:'Paritalo',93:'Erillistalo',112:'Puutalo',113:'Luhtitalo',470:'Kytketty paritalo'}
df['listingType'] = df['listingType'].map(lType)

# %%
# some values in df.district are ''. So i decided to fill them with np.nan and then remove them altogether in the next step
df[df.district == ''] = np.nan

# %%
def count_NAs(df):
    for col in df:
        print(col," : ",df[col].isnull().sum())
        
# def homeSizeLabels(area):
#     """these ranges were calulated by using pd.cut(). 1=Smallest...4=Largest"""
#     if area in range(0,100):
#         return 1
#     elif area in range(100,175):
#         return 2
#     elif area in range(175,250):
#         return 3
#     else:
#         return 4

# %%
# df = df.dropna(inplace = True)
count_NAs(df)
# Out:
# id  :  221
# listingType  :  221
# floor  :  611
# yearBuilt  :  229
# rooms  :  343
# numberOfRooms  :  343
# price  :  343
# city  :  221
# region  :  221
# district  :  221
# postalCode  :  221
# livingArea  :  343
# totalArea  :  343

# %%
# df.dropna(inplace = True)
# count_NAs(df)

# %% [markdown]
# Converting the columns to string and integer(from float) in order to remove the .0 at the end of figures

# %%
# df['id'] = df['id'].astype(str)
# df['floor'] = df['floor'].astype(int)
# df['numberOfRooms'] = df['numberOfRooms'].astype(int)
# df['yearBuilt'] = df['yearBuilt'].astype(int)
# df['postalCode'] = df['postalCode'].astype(str)

# %% [markdown]
# Calculating building age from 'yearBuilt'. Some buildings are supposed to be completed in the future. So any building that gets completed in the future year are also grouped into '1 year old buildings'

# %%
df['buildingAge'] = [1 if x > 2021 else (pd.to_datetime('today').year - pd.to_datetime(x, format = "%Y").year) for x in df.yearBuilt]
# df['centrum'] = [1 if x == 'Keskusta' else 0 for x in df.district]
# df['howBig'] = [homeSizeLabels(x) for x in df.livingArea]

# %%
# hideRows = ['listingGroup', 'yearBuilt', 'imageUrl', 'streetAddress', 'postalCode', 'region', 'link']
df.drop('yearBuilt', axis = 1, inplace = True)
df.reset_index(drop = True)
# Out:
#           id  listingType  floor                           rooms  \
# 0     692440  Omakotitalo    0.0                    5h+k+th+s+at
# 1     507032  Omakotitalo    0.0               4h+k+psh+s+pkh+wc
# 2     506809     Rivitalo    1.0         4h+k+kph+s+wc (kellari)
# 3     698329  Omakotitalo    0.0  4h, k, khh, kph, s, wc, vh, et
# 4        NaN          NaN    NaN                             NaN
# ...      ...          ...    ...                             ...
# 3839  592934     Rivitalo    1.0                           2h, k
# 3840     NaN          NaN    NaN                             NaN
# 3841  578021     Paritalo    1.0                            2h,s
# 3842  573385  Omakotitalo    0.0  4h,k,s+takkahuone/oleskelutila
# 3843  505442   Kerrostalo    2.0                   2h+k+kph+parv
#
#       numberOfRooms      price       city     region                district  \
# 0               5.0  159000.00       Pori       Pori              Leppäkorpi
# 1               4.0   78000.00      Jämsä      Jämsä  Jämsänkoski Koulunmäki
# 2               4.0   89468.56       Oulu       Oulu                 Iinatti
# 3               4.0  139000.00    Pälkäne    Pälkäne              Luopioinen
# 4               NaN        NaN        NaN        NaN                     NaN
# ...             ...        ...        ...        ...                     ...
# 3839            2.0  126000.00      Rauma      Rauma                     Ota
# 3840            NaN        NaN        NaN        NaN                     NaN
# 3841            2.0   84446.92     Imatra     Imatra               Ukonniemi
# 3842            4.0   95000.00  Sastamala  Sastamala         Keikyän Meskala
# 3843            2.0   17412.38      Jämsä      Jämsä    Jämsänkoski Puistola
#
#      postalCode  livingArea  totalArea  buildingAge
# 0         28660       209.0      255.0         30.0
# 1         42300       102.7      149.7         52.0
# 2         90240        92.5       92.5         32.0
# 3         36760       101.5      101.5         12.0
# 4           NaN         NaN        NaN          NaN
# ...         ...         ...        ...          ...
# 3839      26100        81.0       81.0         85.0
# 3840        NaN         NaN        NaN          NaN
# 3841      55420        51.0       51.0         17.0
# 3842      32740       119.0      119.0         47.0
# 3843      42300        59.5       59.5         47.0
#
# [3844 rows x 13 columns]

# %% [markdown]
# The values in the 'rooms' column are separated using , or + or . or * and need to be cleaned

# %%
df.dropna(inplace = True)
count_NAs(df)
# Out:
# id  :  0
# listingType  :  0
# floor  :  0
# rooms  :  0
# numberOfRooms  :  0
# price  :  0
# city  :  0
# region  :  0
# district  :  0
# postalCode  :  0
# livingArea  :  0
# totalArea  :  0
# buildingAge  :  0

# %%
def clean_rooms(item):
    delimiters = "+", ","
    # >>> example = "stackoverflow (c) is awesome... isn't it?"
    regexPattern = '|'.join(map(re.escape, delimiters))
    return([re.sub('\\+|,|\\.|\\*| ', '', x) for x in re.split(regexPattern, item)])

df.rooms = [clean_rooms(x) for x in df.rooms]

# %% [markdown]
# These functions take a single entry from df.rooms and detects the features. These features are then represented with new columns using 1 or 0 denoting the presence or absence of the feature

# %%
def detect_centrum(postalCode):
    if postalCode[2:] == '100':
        return 1
    else:
        return 0

df['centrum'] = [detect_centrum(x) for x in df.postalCode]

def detect_sauna(room): #v4
    if 's' in room or str(room).find('sauna') != -1:
        return 1
    else:
        return 0
df['hasSauna'] = [detect_sauna(x) for x in df.rooms]

def detect_balcony(room): #v3
    if 'p' in room or str(room).find('parv') != -1:
        return 1
    else:
        return 0
df['hasBalcony'] = [detect_balcony(x) for x in df.rooms]

def detect_parking(room): #v3
    if 'ak' in room or 'at' in room or str(room).find('auto') != -1:
        return 1
    else:
        return 0
df['hasParking'] = [detect_parking(x) for x in df.rooms]

def detect_walk_in_closet(room): #v3
    if 'v' in room or 'vh' in room or str(room).find('vaate') != -1:
        return 1
    else:
        return 0
df['hasWalkInCloset'] = [detect_walk_in_closet(x) for x in df.rooms]

def detect_storage_room(room):
    if str(room).find('var') != -1:
        return 1
    else:
        return 0
df['hasStorageRoom'] = [detect_storage_room(x) for x in df.rooms]

# %%
# df.dropna(inplace = True)
# count_NAs(df)

# %%
df.drop('rooms', axis = 1, inplace = True)

# %%
df['id'] = df['id'].astype(str)
df['floor'] = df['floor'].astype(int)
df['numberOfRooms'] = df['numberOfRooms'].astype(int)
df['postalCode'] = df['postalCode'].astype(str)

# %%
df.head()
# Out:
#        id  listingType  floor  numberOfRooms      price       city     region  \
# 0  692440  Omakotitalo      0              5  159000.00       Pori       Pori
# 1  507032  Omakotitalo      0              4   78000.00      Jämsä      Jämsä
# 2  506809     Rivitalo      1              4   89468.56       Oulu       Oulu
# 3  698329  Omakotitalo      0              4  139000.00    Pälkäne    Pälkäne
# 5  508029     Rivitalo      1              2  127000.00  Jyväskylä  Jyväskylä
#
#                  district postalCode  livingArea  totalArea  buildingAge  \
# 0              Leppäkorpi      28660       209.0      255.0         30.0
# 1  Jämsänkoski Koulunmäki      42300       102.7      149.7         52.0
# 2                 Iinatti      90240        92.5       92.5         32.0
# 3              Luopioinen      36760       101.5      101.5         12.0
# 5               Heinämäki      40270        59.0       59.0         32.0
#
#    centrum  hasSauna  hasBalcony  hasParking  hasWalkInCloset  hasStorageRoom
# 0        0         1           0           1                0               0
# 1        0         1           0           0                0               0
# 2        0         1           0           0                0               0
# 3        0         1           0           0                1               0
# 5        0         1           0           0                0               0

# %%
set(df.listingType)
# Out:
# {'Erillistalo',
#  'Kerrostalo',
#  'Kytketty paritalo',
#  'Luhtitalo',
#  'Omakotitalo',
#  'Paritalo',
#  'Puutalo',
#  'Rivitalo'}

# %% [markdown]
# Exporting the dataframe to a csv file

# %%
df.to_csv(f'op-koti.csv', sep=',', encoding='utf-8', index=False)
