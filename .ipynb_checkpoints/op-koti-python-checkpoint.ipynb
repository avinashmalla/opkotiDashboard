# %% [markdown]
# # Data collected from OP's website op-koti.fi. Initially I used webscraping technique to collect data. But using the API was more dynamic and easy to handle

# %%
import numpy as np
import pandas as pd
import requests
# import math
import re
from pandas import json_normalize

pd.options.display.max_columns = None
# display(df)

# %%
URL = 'https://op-koti.fi/api/apartments?mode=sale&featureGroup=apartment&orderBy=created&order=desc&offset=0&limit=4500'
# request the URL and parse the JSON
response = requests.get(URL)
response.raise_for_status() # raise exception if invalid response
data = response.json()['listings']

# normalizing the json data into a dataframe
df = json_normalize(data, max_level = 1)

# %%
df.head(10)
# Out:
#        id kipinaId  listingType commission  listingGroup  source  \
# 0  515120   439810           89          O            82  Kipinä
# 1  514798   439488           89          O            82  Kipinä
# 2  514736   439426           89          O            82  Kipinä
# 3  514777   439467           89          O            82  Kipinä
# 4  515224   439914           90          K            82  Kipinä
# 5  515223   439913           89          O            82  Kipinä
# 6  515345   440035           91          O            82  Kipinä
# 7  691117   415816           89          O            82  Kipinä
# 8  515267   439957           90          K            82  Kipinä
# 9  515264   439954           89          O            82  Kipinä
#
#                     created featureGroups  floor    year  \
# 0  2021-09-16T09:09:46.609Z   [apartment]    3.0  1951.0
# 1   2021-09-16T09:09:33.79Z   [apartment]    3.0  1990.0
# 2  2021-09-16T09:09:32.961Z   [apartment]    3.0  1974.0
# 3  2021-09-16T09:09:20.339Z   [apartment]    2.0  1956.0
# 4  2021-09-16T08:09:37.094Z   [apartment]    0.0  2006.0
# 5  2021-09-16T08:09:34.223Z   [apartment]    4.0  2012.0
# 6  2021-09-16T08:09:31.419Z   [apartment]    1.0  1992.0
# 7  2021-09-16T08:09:26.961Z   [apartment]    2.0  2018.0
# 8  2021-09-16T08:09:14.475Z   [apartment]    0.0  2007.0
# 9  2021-09-16T08:09:09.813Z   [apartment]    3.0  1963.0
#
#                                             imageUrl  \
# 0  https://op-koti.fi/kuvat/515120/d3cba19b0cf95b...
# 1  https://op-koti.fi/kuvat/514798/66a3ead0af9486...
# 2  https://op-koti.fi/kuvat/514736/ab2f791b549a25...
# 3  https://op-koti.fi/kuvat/514777/35e75eee5f0a50...
# 4  https://op-koti.fi/kuvat/515224/f9409cad242bb7...
# 5  https://op-koti.fi/kuvat/515223/622a06bd07ccc0...
# 6  https://op-koti.fi/kuvat/515345/9303b8b00179bd...
# 7  https://op-koti.fi/kuvat/691117/97614b72abf4be...
# 8  https://op-koti.fi/kuvat/515267/c0c17f3126f109...
# 9  https://op-koti.fi/kuvat/515264/683e7ca1612e58...
#
#                                             showings  \
# 0  [{'showingType': 'unknown', 'date': '20.9.', '...
# 1                                                 []
# 2  [{'showingType': 'unknown', 'date': '19.9.', '...
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9  [{'showingType': 'live', 'date': '20.9.', 'sta...
#
#                                           rooms  numberOfRooms      price  \
# 0                                          2h+k            2.0   68000.00
# 1                         2h,k,kh,vh,et,parveke            2.0   65950.00
# 2                      3h+k+kph+lasitettu parv.            3.0  153878.05
# 3                                   2h,kk,kh,et            2.0   79000.00
# 4     3h,k,kph,s,eril.wc,khh,vh+katettu terassi            3.0  285000.00
# 5        3h+keittiö+kph+sauna+lasitettu parveke            3.0  199000.00
# 6                                        3h,k,s            3.0  118529.48
# 7                                        2h,k,s            2.0   55812.36
# 8  2h,tupak,khh,ph,s,wc,et,tk,varasto,autokatos            3.0  189000.00
# 9                              1h,k,kph,parveke            1.0   98000.00
#
#    debtFreePrice rentPerMonth   location.streetAddress location.postalCode  \
# 0        68000.0         None          Tehdaskatu 12 A               87100
# 1        69000.0         None     Jatulikivenkatu 14 A               90240
# 2       158000.0         None          Pähkinätie 12 A               01710
# 3        79000.0         None            Ratakatu 14 D               90130
# 4            NaN         None            Hankaluhta 11               09630
# 5       199000.0         None              Turotie 2 A               40250
# 6       122000.0         None  Pöllösenlahdenkatu 13 B               74130
# 7       138000.0         None         Veskantie 1 A as               85800
# 8            NaN         None            Niittupolku 8               11130
# 9        98000.0         None       Ahvenistonkatu 3 B               15100
#
#   location.postOffice location.city  location.cityId location.region  \
# 0             KAJAANI       Kajaani              205         Kajaani
# 1                OULU          Oulu              564            Oulu
# 2              VANTAA        Vantaa               92    Länsi-Vantaa
# 3                OULU          Oulu              564            Oulu
# 4           KOISJÄRVI         Lohja              444           Lohja
# 5           JYVÄSKYLÄ     Jyväskylä              179       Jyväskylä
# 6             IISALMI       Iisalmi              140         Iisalmi
# 7          HAAPAJÄRVI    Haapajärvi               69      Haapajärvi
# 8           RIIHIMÄKI     Riihimäki              694       Riihimäki
# 9               LAHTI         Lahti              398           Lahti
#
#    location.regionId location.district  location.districtId  \
# 0                146          Keskusta               2430.0
# 1                299          Maikkula               2613.0
# 2                 60      Pähkinärinne                996.0
# 3                299           Raksila               2596.0
# 4                257           Paksalo              10837.0
# 5                138         Lohikoski               2301.0
# 6                115     Pöllösenlahti               5478.0
# 7                 88                                    NaN
# 8                355            Uhkola               1434.0
# 9                 35          Keskusta               1058.0
#
#                           location.streetId  \
# 0  435f671ad859cf28e067e6edbb983ef50b7286e4
# 1  86fbe6c615fa6a3726c6fe69ab5f031a955e26e4
# 2  f91567441b5a3464ead480adf2bd23c7fbe7c427
# 3  65c2efea54086c79dd45e93ffe6e73268bfe6382
# 4  512ee4ffb0967c957bc5a58c3382091a254f17e2
# 5  eb08535ad13bfa4c5679595b5439dec741c893b6
# 6  dcfc19bc31f40dd07d5ee4d73995a76604d8e8b0
# 7  89d7dc41f04d38f80171c0109d76b2cb63d7a408
# 8  8573583c3527616d717ed577426bbb87a6fca0bd
# 9  bdb6fd84d34c8e0a399e1020d77801352cfece86
#
#                             location.coordinates  \
# 0  {'latitude': 64.22817, 'longitude': 27.71784}
# 1    {'latitude': 64.982, 'longitude': 25.57743}
# 2  {'latitude': 60.26408, 'longitude': 24.80195}
# 3  {'latitude': 65.00796, 'longitude': 25.48364}
# 4  {'latitude': 60.37475, 'longitude': 24.12382}
# 5   {'latitude': 62.26692, 'longitude': 25.7569}
# 6  {'latitude': 63.55621, 'longitude': 27.22464}
# 7  {'latitude': 63.75249, 'longitude': 25.31527}
# 8  {'latitude': 60.74068, 'longitude': 24.80632}
# 9  {'latitude': 60.98188, 'longitude': 25.64785}
#
#                   housing.livingArea                   housing.totalArea  \
# 0  {'size': 51, 'displayUnit': 'm2'}   {'size': 51, 'displayUnit': 'm2'}
# 1  {'size': 43, 'displayUnit': 'm2'}   {'size': 43, 'displayUnit': 'm2'}
# 2  {'size': 67, 'displayUnit': 'm2'}   {'size': 67, 'displayUnit': 'm2'}
# 3  {'size': 44, 'displayUnit': 'm2'}   {'size': 44, 'displayUnit': 'm2'}
# 4  {'size': 96, 'displayUnit': 'm2'}  {'size': 149, 'displayUnit': 'm2'}
# 5  {'size': 68, 'displayUnit': 'm2'}   {'size': 68, 'displayUnit': 'm2'}
# 6  {'size': 77, 'displayUnit': 'm2'}   {'size': 77, 'displayUnit': 'm2'}
# 7  {'size': 53, 'displayUnit': 'm2'}   {'size': 53, 'displayUnit': 'm2'}
# 8  {'size': 89, 'displayUnit': 'm2'}  {'size': 108, 'displayUnit': 'm2'}
# 9  {'size': 35, 'displayUnit': 'm2'}   {'size': 35, 'displayUnit': 'm2'}
#
#                       housing.siteArea  \
# 0   {'size': 982, 'displayUnit': 'm2'}
# 1  {'size': 5180, 'displayUnit': 'm2'}
# 2  {'size': 4464, 'displayUnit': 'm2'}
# 3  {'size': 2240, 'displayUnit': 'm2'}
# 4  {'size': 5000, 'displayUnit': 'm2'}
# 5  {'size': 4257, 'displayUnit': 'm2'}
# 6  {'size': 6115, 'displayUnit': 'm2'}
# 7  {'size': 2778, 'displayUnit': 'm2'}
# 8   {'size': 851, 'displayUnit': 'm2'}
# 9  {'size': 1858, 'displayUnit': 'm2'}
#
#                                   housing.rooms  housing.numberOfRooms  \
# 0                                          2h+k                    2.0
# 1                         2h,k,kh,vh,et,parveke                    2.0
# 2                      3h+k+kph+lasitettu parv.                    3.0
# 3                                   2h,kk,kh,et                    2.0
# 4     3h,k,kph,s,eril.wc,khh,vh+katettu terassi                    3.0
# 5        3h+keittiö+kph+sauna+lasitettu parveke                    3.0
# 6                                        3h,k,s                    3.0
# 7                                        2h,k,s                    2.0
# 8  2h,tupak,khh,ph,s,wc,et,tk,varasto,autokatos                    3.0
# 9                              1h,k,kph,parveke                    1.0
#
#    pricing.price  pricing.debtFreePrice  livingArea.size  \
# 0       68000.00                68000.0             51.0
# 1       65950.00                69000.0             43.0
# 2      153878.05               158000.0             67.0
# 3       79000.00                79000.0             44.0
# 4      285000.00                    NaN             96.0
# 5      199000.00               199000.0             68.0
# 6      118529.48               122000.0             77.0
# 7       55812.36               138000.0             53.0
# 8      189000.00                    NaN             89.0
# 9       98000.00                98000.0             35.0
#
#   livingArea.displayUnit  totalArea.size totalArea.displayUnit  siteArea.size  \
# 0                     m2            51.0                    m2          982.0
# 1                     m2            43.0                    m2         5180.0
# 2                     m2            67.0                    m2         4464.0
# 3                     m2            44.0                    m2         2240.0
# 4                     m2           149.0                    m2         5000.0
# 5                     m2            68.0                    m2         4257.0
# 6                     m2            77.0                    m2         6115.0
# 7                     m2            53.0                    m2         2778.0
# 8                     m2           108.0                    m2          851.0
# 9                     m2            35.0                    m2         1858.0
#
#   siteArea.displayUnit                             virtualPresentationUrl  \
# 0                   m2                                                NaN
# 1                   m2                                                NaN
# 2                   m2                                                NaN
# 3                   m2                                                NaN
# 4                   m2  https://zimg.zentuvo.com/zhome/?project=161a62...
# 5                   m2                                                NaN
# 6                   m2                                                NaN
# 7                   m2                                                NaN
# 8                   m2                                                NaN
# 9                   m2                                                NaN
#
#                                             videoUrl  siteArea  livingArea  \
# 0                                                NaN       NaN         NaN
# 1                                                NaN       NaN         NaN
# 2                                                NaN       NaN         NaN
# 3                                                NaN       NaN         NaN
# 4  https://zimg.zentuvo.com/zhome/?project=161a62...       NaN         NaN
# 5                                                NaN       NaN         NaN
# 6                                                NaN       NaN         NaN
# 7                                                NaN       NaN         NaN
# 8                                                NaN       NaN         NaN
# 9                                                NaN       NaN         NaN
#
#    totalArea newHousing.newHousingId newHousing.name
# 0        NaN                     NaN             NaN
# 1        NaN                     NaN             NaN
# 2        NaN                     NaN             NaN
# 3        NaN                     NaN             NaN
# 4        NaN                     NaN             NaN
# 5        NaN                     NaN             NaN
# 6        NaN                     NaN             NaN
# 7        NaN                     NaN             NaN
# 8        NaN                     NaN             NaN
# 9        NaN                     NaN             NaN

# %%
# df[df.id == '696611']
# display(df)

# %% [markdown]
# It can be seen above that the dataframe contains multiple columns that are irrelevant to us. Relevant columns are selected as shown below.

# %%
df.columns
# Out:
# Index(['id', 'kipinaId', 'listingType', 'commission', 'listingGroup', 'source',
#        'created', 'featureGroups', 'floor', 'year', 'imageUrl', 'showings',
#        'rooms', 'numberOfRooms', 'price', 'debtFreePrice', 'rentPerMonth',
#        'location.streetAddress', 'location.postalCode', 'location.postOffice',
#        'location.city', 'location.cityId', 'location.region',
#        'location.regionId', 'location.district', 'location.districtId',
#        'location.streetId', 'location.coordinates', 'housing.livingArea',
#        'housing.totalArea', 'housing.siteArea', 'housing.rooms',
#        'housing.numberOfRooms', 'pricing.price', 'pricing.debtFreePrice',
#        'livingArea.size', 'livingArea.displayUnit', 'totalArea.size',
#        'totalArea.displayUnit', 'siteArea.size', 'siteArea.displayUnit',
#        'virtualPresentationUrl', 'videoUrl', 'siteArea', 'livingArea',
#        'totalArea', 'newHousing.newHousingId', 'newHousing.name'],
#       dtype='object')

# %%
cols = ['id', 'listingType', 'floor', 'year', 'rooms', 'numberOfRooms', 'price', 'debtFreePrice',
       'location.city', 'location.region', 'location.district','location.postalCode',
       'livingArea.size', 'totalArea.size']

df = df[cols]

# %% [markdown]
# Renaming the cols

# %%
df = df.rename(columns = {'location.city':'city','location.region':'region','location.district':'district','location.postalCode':'postalCode','livingArea.size':'livingArea','totalArea.size':'totalArea', 'year':'yearBuilt'})

# %% [markdown]
# Mapping the listingType column to the apporpriate type of house (extracted from the website manually)

# %%
lType = {89:'Kerrostalo',90:'Omakotitalo',91:'Rivitalo',92:'Paritalo',93:'Erillistalo',112:'Puutalo',113:'Luhtitalo',470:'Kytketty paritalo'}
df['listingType'] = df['listingType'].map(lType)

# %%
# some values in df.district are ''. So i decided to fill them with np.nan and then remove them altogether in the next step
df[df.district == ''] = np.nan

# %%
def count_NAs(df):
    for col in df:
        print(col," : ",df[col].isnull().sum())
        
# def homeSizeLabels(area):
#     """these ranges were calulated by using pd.cut(). 1=Smallest...4=Largest"""
#     if area in range(0,100):
#         return 1
#     elif area in range(100,175):
#         return 2
#     elif area in range(175,250):
#         return 3
#     else:
#         return 4

# %%
# df = df.dropna(inplace = True)
count_NAs(df)
# Out:
# id  :  214
# listingType  :  214
# floor  :  619
# yearBuilt  :  221
# rooms  :  322
# numberOfRooms  :  322
# price  :  322
# debtFreePrice  :  1439
# city  :  214
# region  :  214
# district  :  214
# postalCode  :  214
# livingArea  :  322
# totalArea  :  322

# %% [markdown]
# There are some columns with null values for debtFreePrice. Those values are replaced by price.

# %%
df.loc[df.debtFreePrice.isnull() & df.price.notnull(),['debtFreePrice']] = df.price

# %% [markdown]
# Converting the columns to string and integer(from float) in order to remove the .0 at the end of figures

# %%
# df['id'] = df['id'].astype(str)
# df['floor'] = df['floor'].astype(int)
# df['numberOfRooms'] = df['numberOfRooms'].astype(int)
# df['yearBuilt'] = df['yearBuilt'].astype(int)
# df['postalCode'] = df['postalCode'].astype(str)

# %% [markdown]
# Calculating building age from 'yearBuilt'. Some buildings are supposed to be completed in the future. So any building that gets completed in the future year are also grouped into '1 year old buildings'

# %%
df['buildingAge'] = [1 if x > 2021 else (pd.to_datetime('today').year - pd.to_datetime(x, format = "%Y").year) for x in df.yearBuilt]
# df['centrum'] = [1 if x == 'Keskusta' else 0 for x in df.district]
# df['howBig'] = [homeSizeLabels(x) for x in df.livingArea]

# %%
# hideRows = ['listingGroup', 'yearBuilt', 'imageUrl', 'streetAddress', 'postalCode', 'region', 'link']
df.drop('yearBuilt', axis = 1, inplace = True)
df.reset_index(drop = True)
# Out:
#                                       id  listingType  floor  \
# 0                                 515120   Kerrostalo    3.0
# 1                                 514798   Kerrostalo    3.0
# 2                                 514736   Kerrostalo    3.0
# 3                                 514777   Kerrostalo    2.0
# 4                                 515224  Omakotitalo    0.0
# ...                                  ...          ...    ...
# 3593  kiinteisto-oy-joensuun-koskikatu-9   Kerrostalo    NaN
# 3594                                 NaN          NaN    NaN
# 3595                              604375   Kerrostalo    1.0
# 3596                                 NaN          NaN    NaN
# 3597                              592934     Rivitalo    1.0
#
#                                           rooms  numberOfRooms      price  \
# 0                                          2h+k            2.0   68000.00
# 1                         2h,k,kh,vh,et,parveke            2.0   65950.00
# 2                      3h+k+kph+lasitettu parv.            3.0  153878.05
# 3                                   2h,kk,kh,et            2.0   79000.00
# 4     3h,k,kph,s,eril.wc,khh,vh+katettu terassi            3.0  285000.00
# ...                                         ...            ...        ...
# 3593                                       None            NaN        NaN
# 3594                                        NaN            NaN        NaN
# 3595                                       1h,k            1.0   18500.00
# 3596                                        NaN            NaN        NaN
# 3597                                      2h, k            2.0  126000.00
#
#       debtFreePrice     city        region      district postalCode  \
# 0           68000.0  Kajaani       Kajaani      Keskusta      87100
# 1           69000.0     Oulu          Oulu      Maikkula      90240
# 2          158000.0   Vantaa  Länsi-Vantaa  Pähkinärinne      01710
# 3           79000.0     Oulu          Oulu       Raksila      90130
# 4          285000.0    Lohja         Lohja       Paksalo      09630
# ...             ...      ...           ...           ...        ...
# 3593            NaN  Joensuu       Joensuu      Keskusta      80100
# 3594            NaN      NaN           NaN           NaN        NaN
# 3595        18500.0   Virrat        Virrat       Nallela      34800
# 3596            NaN      NaN           NaN           NaN        NaN
# 3597       126000.0    Rauma         Rauma           Ota      26100
#
#       livingArea  totalArea  buildingAge
# 0           51.0       51.0         70.0
# 1           43.0       43.0         31.0
# 2           67.0       67.0         47.0
# 3           44.0       44.0         65.0
# 4           96.0      149.0         15.0
# ...          ...        ...          ...
# 3593         NaN        NaN          6.0
# 3594         NaN        NaN          NaN
# 3595        30.0       30.0         51.0
# 3596         NaN        NaN          NaN
# 3597        81.0       81.0         85.0
#
# [3598 rows x 14 columns]

# %% [markdown]
# The values in the 'rooms' column are separated using , or + or . or * and need to be cleaned

# %%
df.dropna(inplace = True)
count_NAs(df)
# Out:
# id  :  0
# listingType  :  0
# floor  :  0
# rooms  :  0
# numberOfRooms  :  0
# price  :  0
# debtFreePrice  :  0
# city  :  0
# region  :  0
# district  :  0
# postalCode  :  0
# livingArea  :  0
# totalArea  :  0
# buildingAge  :  0

# %%
def clean_rooms(item):
    delimiters = "+", ","
    # >>> example = "stackoverflow (c) is awesome... isn't it?"
    regexPattern = '|'.join(map(re.escape, delimiters))
    return([re.sub('\\+|,|\\.|\\*| ', '', x) for x in re.split(regexPattern, item)])

df.rooms = [clean_rooms(x) for x in df.rooms]

# %% [markdown]
# These functions take a single entry from df.rooms and detects the features. These features are then represented with new columns using 1 or 0 denoting the presence or absence of the feature

# %%
def detect_centrum(postalCode):
    if postalCode[2:] == '100':
        return 1
    else:
        return 0

df['centrum'] = [detect_centrum(x) for x in df.postalCode]

def detect_sauna(room): #v4
    if 's' in room or str(room).find('sauna') != -1:
        return 1
    else:
        return 0
df['hasSauna'] = [detect_sauna(x) for x in df.rooms]

def detect_balcony(room): #v3
    if 'p' in room or str(room).find('parv') != -1:
        return 1
    else:
        return 0
df['hasBalcony'] = [detect_balcony(x) for x in df.rooms]

def detect_parking(room): #v3
    if 'ak' in room or 'at' in room or str(room).find('auto') != -1:
        return 1
    else:
        return 0
df['hasParking'] = [detect_parking(x) for x in df.rooms]

def detect_walk_in_closet(room): #v3
    if 'v' in room or 'vh' in room or str(room).find('vaate') != -1:
        return 1
    else:
        return 0
df['hasWalkInCloset'] = [detect_walk_in_closet(x) for x in df.rooms]

def detect_storage_room(room):
    if str(room).find('var') != -1:
        return 1
    else:
        return 0
df['hasStorageRoom'] = [detect_storage_room(x) for x in df.rooms]

# %%
df.drop('rooms', axis = 1, inplace = True)

# %%
df['id'] = df['id'].astype(str)
df['floor'] = df['floor'].astype(int)
df['numberOfRooms'] = df['numberOfRooms'].astype(int)
df['postalCode'] = df['postalCode'].astype(str)

# %%
df.head()
# Out:
#        id  listingType  floor  numberOfRooms      price  debtFreePrice  \
# 0  515120   Kerrostalo      3              2   68000.00        68000.0
# 1  514798   Kerrostalo      3              2   65950.00        69000.0
# 2  514736   Kerrostalo      3              3  153878.05       158000.0
# 3  514777   Kerrostalo      2              2   79000.00        79000.0
# 4  515224  Omakotitalo      0              3  285000.00       285000.0
#
#       city        region      district postalCode  livingArea  totalArea  \
# 0  Kajaani       Kajaani      Keskusta      87100        51.0       51.0
# 1     Oulu          Oulu      Maikkula      90240        43.0       43.0
# 2   Vantaa  Länsi-Vantaa  Pähkinärinne      01710        67.0       67.0
# 3     Oulu          Oulu       Raksila      90130        44.0       44.0
# 4    Lohja         Lohja       Paksalo      09630        96.0      149.0
#
#    buildingAge  centrum  hasSauna  hasBalcony  hasParking  hasWalkInCloset  \
# 0         70.0        1         0           0           0                0
# 1         31.0        0         0           1           0                1
# 2         47.0        0         0           1           0                0
# 3         65.0        0         0           0           0                0
# 4         15.0        0         1           0           0                1
#
#    hasStorageRoom
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
set(df.listingType)
# Out:
# {'Erillistalo',
#  'Kerrostalo',
#  'Kytketty paritalo',
#  'Luhtitalo',
#  'Omakotitalo',
#  'Paritalo',
#  'Puutalo',
#  'Rivitalo'}

# %% [markdown]
# Exporting the dataframe to a csv file

# %%
df.to_csv(f'op-koti.csv', sep=',', encoding='utf-8', index=False)
